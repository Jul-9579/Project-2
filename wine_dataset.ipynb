# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_wine = pd.read_csv('winequality-red.csv', sep=";")
white_wine = pd.read_csv('winequality-white.csv', sep=";")

# %% [markdown]
# ## Epic 3: Data Wrangling

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine.shape
# Out:
# (4898, 12)

# %%
red_wine.isna().value_counts()
# Out:
# fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density  pH     sulphates  alcohol  quality
# False          False             False        False           False      False                False                 False    False  False      False    False      1599
# Name: count, dtype: int64

# %%
red_wine.isnull().value_counts()
# Out:
# fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density  pH     sulphates  alcohol  quality
# False          False             False        False           False      False                False                 False    False  False      False    False      1599
# Name: count, dtype: int64

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
inplace=True

# here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])
inplace=True

# %%
red_wine["wine_type"] = "red" 
inplace=True
display(red_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
inplace=True

# here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])
inplace=True

# %%
white_wine["wine_type"] = "white" 
inplace=True
display(white_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
all_wines = pd.concat([red_wine, white_wine])
inplace=True
all_wines.shape
# Out:
# (6497, 14)

# %% [markdown]
# ## Epic 3: Exploratory Analysis

# %%
pd.set_option('display.max_columns', None)
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"],).round(3)
# mean value of sulfates and volatile acidity seem to be higher in red wine as compared to white wine
# mean of residual sugar is higher for white wines
# mean of free suflur dioxide and total sulfur dioxide higher for white wines
# mean of alcohol is similar
# mean of quality is similar, but slightly higher for white wines
# standard deviation for free and total sulfur dioxide is high for white and red wines
# Out:
#       Red Wines Stats                                                        \
#         fixed acidity volatile acidity citric acid residual sugar chlorides
# count        1599.000         1599.000    1599.000       1599.000  1599.000
# mean            8.320            0.528       0.271          2.539     0.087
# std             1.741            0.179       0.195          1.410     0.047
# min             4.600            0.120       0.000          0.900     0.012
# 25%             7.100            0.390       0.090          1.900     0.070
# 50%             7.900            0.520       0.260          2.200     0.079
# 75%             9.200            0.640       0.420          2.600     0.090
# max            15.900            1.580       1.000         15.500     0.611
#
#                                                                               \
#       free sulfur dioxide total sulfur dioxide   density        pH sulphates
# ...

# %%
print(len(white_wine))
print(len(red_wine))
# Out:
# 4898
# 1599

# %%
all_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  quality_label         6497 non-null   category
#  13  wine_type             6497 non-null   object
# ...

# %%
all_wines["wine_type"] = all_wines["wine_type"].astype("category")

# %%
# wine_count = all_wines["wine_type"].value_counts()
# labels = "red", "white"
# wine_category = all_wines["wine_type"]
# plt.pie(wine_count, labels=labels)
# plt.show()

# %%
wine_count = all_wines["wine_type"].value_counts()
explode = (0, 0.1) 
fig, ax = plt.subplots()
plt.pie(wine_count, explode=explode, labels=wine_count.index, colors=["#d4c52d", "#7B0323"], autopct='%1.1f%%')
plt.title("Distribution of Wine Types")
plt.show()

# %%
sns.histplot(white_wine["quality_label"])
plt.title("White Wine")
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
sns.histplot(red_wine["quality_label"])
plt.title("Red Wine")
# Out:
# Text(0.5, 1.0, 'Red Wine')

# %%
x = (red_wine["quality_label"])
y = (white_wine["quality_label"])
plt.hist([x,y])
plt.show()

# %%
# fig, axes = plt.subplots(1, 1)
# sns.histplot(data=white_wine, x="quality_label", ax=axes[0, 0])
# sns.histplot(data=red_wine, x="quality_label", ax=axes[0, 1])
# plt.show()

# %%
fig, axs = plt.subplots(1,2, sharey=True, figsize=(8,5))
plt.subplot(1,2,1)
sns.histplot(white_wine["quality_label"], color="#eccd13", shrink=.8)
# plt.xticks(visible=False)
plt.title("White Wine")
plt.xlabel(None)

plt.subplot(1,2,2)
sns.histplot(red_wine["quality_label"], color="#7B0323", shrink=.8)
plt.title("Red Wine")
plt.xlabel(None)
# plt.xticks(visible=False)
plt.show()

# %%
sns.boxplot(x='quality_label', y='alcohol', data=all_wines)
plt.show()

# %%
sns.boxplot(x='quality_label', y='pH', data=all_wines)
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5))
plt.subplot(1,2,1)
sns.boxplot(x='quality_label', y='alcohol', data=all_wines, hue="quality_label")
plt.xlabel("Wine Class Quality")
plt.ylabel("Wine Alcohol %")
plt.subplot(1,2,2)
sns.boxplot(x='quality_label', y='pH', data=all_wines, hue="quality_label")
plt.xlabel("Wine Class Quality")
plt.ylabel("Wine pH")
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5))
plt.subplot(1,2,1)
sns.boxplot(x='quality_label', y='sulphates', data=white_wine, hue="quality_label", palette="magma")
plt.xlabel("Wine Class Quality")
plt.ylabel("Sulphates")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.boxplot(x='quality_label', y='sulphates', data=red_wine, hue="quality_label", palette="magma")
plt.xlabel("Wine Class Quality")
plt.ylabel("Sulphates")
plt.title("Red Wine")

plt.show()

# For red wine high quality wine tend to contain more sulphates
# Low quality red wines have much more outliers
# For white wines sulphates doesn't seem to impact the quality so much

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5))
plt.subplot(1,2,1)
sns.boxplot(x='quality_label', y='density', data=white_wine, hue="quality_label", palette="magma")
plt.xlabel("Wine Class Quality")
plt.ylabel("Density")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.boxplot(x='quality_label', y='density', data=red_wine, hue="quality_label", palette="magma")
plt.xlabel("Wine Class Quality")
plt.ylabel("Density")
plt.title("Red Wine")

plt.show()

# %%
sns.kdeplot(data=all_wines, x="alcohol", hue="wine_type")
plt.show()

# %%
sns.displot(data = all_wines, x='sulphates', hue="wine_type", kind="kde")
plt.show()

# %%
# fg = sns.FacetGrid(data=all_wines, col="time", row="smoker")
# fg = fg.map(plt.hist, "total_bill")

# %%
# sns.pairplot(all_wines)
sns.pairplot(all_wines[["alcohol", "quality"]])
plt.show()

# %%
sns.jointplot(data=all_wines, x='quality', y='alcohol')
plt.show()

# %%
sns.jointplot(x='quality', y='alcohol', data=all_wines, kind='reg')
plt.show()

# %%
sns.barplot(data=red_wine, x='quality', y='alcohol', color="#7B0323")
plt.show()

# %%
sns.barplot(data=white_wine, x='quality', y='alcohol', color="#eccd13")
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality', y='alcohol', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality")
plt.ylabel("Alcohol")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality', y='alcohol', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality")
plt.ylabel("Alcohol")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='fixed acidity', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Fixed Acidity")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='fixed acidity', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Fixed Acidity")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='residual sugar', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Residual Sugar")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='residual sugar', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Residual Sugar")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='volatile acidity', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Volatile Acidity")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='volatile acidity', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Volatile Acidity")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5))
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='citric acid', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Citric Acid")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='citric acid', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Citric Acid")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='chlorides', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Chlorides")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='chlorides', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Chlorides")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='free sulfur dioxide', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Free Sulfur Dioxide")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='free sulfur dioxide', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Free Sulfur Dioxide")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='total sulfur dioxide', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Total Sulfur Dioxide")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='total sulfur dioxide', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Total Sulfur Dioxide")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='density', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Density")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='density', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Density")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='pH', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("pH")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='pH', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("pH")
plt.title("Red Wine")

plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,5), sharey=True)
plt.subplot(1,2,1)
sns.barplot(x='quality_label', y='sulphates', data=white_wine, errorbar=None, color="#eccd13")
plt.xlabel("Quality Label")
plt.ylabel("Sulphates")
plt.title("White Wine")

plt.subplot(1,2,2)
sns.barplot(x='quality_label', y='sulphates', data=red_wine, errorbar=None, color="#7B0323")
plt.xlabel("Quality Label")
plt.ylabel("Sulphates")
plt.title("Red Wine")

plt.show()

# %%
sns.lmplot(x='quality', y='residual sugar', data=white_wine)
plt.show()

# %%
custom_colors = ["#7B0323", "#eccd13"]

features = ["fixed acidity", "citric acid", "volatile acidity", "residual sugar",
            "chlorides", "free sulfur dioxide", "total sulfur dioxide", "density",
            "pH", "sulphates", "alcohol"]

fig, axs = plt.subplots(6,2,sharex=True, figsize=(10,25))

axs = axs.flatten()

# Loop through the features and plot
for i, feature in enumerate(features):
    sns.barplot(x="wine_type", y=feature, data=all_wines, hue="wine_type",
                palette="inferno", ax=axs[i])
    axs[i].set_title(feature)

# Remove the last empty subplot (axs[11])
fig.delaxes(axs[-1])  

# Adjust layout
fig.subplots_adjust(hspace=0.2)

# Show plot
plt.show()

# %% [markdown]
# ## Heatmap

# %% [markdown]
# ### Heatmap - White Wine

# %%
num_white = white_wine.select_dtypes(include='number')
num_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
tw = num_white.corr()
tw
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(tw, vmin=-1, cmap="YlOrBr", annot=True, fmt=".1f", linewidth=.7)
# Out:
# <Axes: >

# %% [markdown]
# ### Heatmap - Red Wine

# %%
num_red = red_wine.select_dtypes(include='number')
num_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
tr = num_red.corr()
tr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(tr, vmin=-1, cmap="Reds", annot=True, fmt=".1f", linewidth=.7)
plt.title("Red Wines")
plt.show()

# %% [markdown]
# ### Heatmap - All Wines

# %%
num_all = all_wines.select_dtypes(include='number')
t_all = num_all.corr()
t_all
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(t_all, vmin=-1, cmap="Blues", annot=True, fmt=".1f", linewidth=.7)
plt.title("White Wines")
plt.show()

# %% [markdown]
# ### Heatmap - White Wine (High Quality)

# %%
num_whitehq = white_wine[(white_wine["quality"] >7)].select_dtypes(include='number')
num_whitehq
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 17              6.2             0.660         0.48             1.2      0.029
# 20              6.2             0.660         0.48             1.2      0.029
# 22              6.8             0.260         0.42             1.7      0.049
# 68              6.7             0.230         0.31             2.1      0.046
# 74              6.7             0.230         0.31             2.1      0.046
# ...             ...               ...          ...             ...        ...
# 4765            5.2             0.300         0.34             1.5      0.038
# 4766            6.4             0.320         0.25             5.0      0.055
# 4786            4.4             0.320         0.39             4.3      0.030
# 4787            3.9             0.225         0.40             4.2      0.030
# 4802            5.8             0.280         0.34             2.2      0.037
#
# ...

# %%
twhq = num_whitehq.corr()
twhq
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.127194     0.208770
# volatile acidity          -0.127194          1.000000    -0.147040
# citric acid                0.208770         -0.147040     1.000000
# residual sugar             0.330405         -0.134262     0.029784
# chlorides                  0.279024         -0.303084    -0.118231
# free sulfur dioxide        0.018722         -0.185010     0.014152
# total sulfur dioxide       0.257586         -0.181347     0.054321
# density                    0.558859         -0.368117     0.073389
# pH                        -0.456184          0.057226     0.096858
# sulphates                 -0.127535         -0.154548    -0.017107
# alcohol                   -0.437522          0.520520     0.005621
# quality                    0.151345          0.031753     0.114402
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(twhq, vmin=-1, cmap="YlOrBr", annot=True, fmt=".1f", linewidth=.7)
plt.title("High Quality White Wines")
plt.show()

# %% [markdown]
# ### FacetGrid: Wine Type - Composition

# %%
fg = sns.FacetGrid(all_wines, col="wine_type")
fg = fg.map(sns.scatterplot, "quality", "density")

# %%
fg = sns.FacetGrid(all_wines, col="wine_type")
fg = fg.map(sns.scatterplot, "quality", "citric acid")

# %%
fg = sns.FacetGrid(all_wines, col="quality_label", row="wine_type")
fg = fg.map(sns.scatterplot, "residual sugar", "density")

# %%
# sns.lmplot(x='fixed acidity', y='density', data=white_wine)
sns.lmplot(x='fixed acidity', y='density', data=all_wines, col='quality_label', row='wine_type')
plt.show()

# %%
sns.lmplot(x='alcohol', y='density', data=all_wines, col='quality_label', row='wine_type')
plt.show()

# %% [markdown]
# # Sprint 2
# ## Epic 1: Univariate Analysis

# %%
red_wine.hist(bins=15, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))
plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)
# Out:
# Text(0.65, 1.25, 'Red Wine Univariate Plots')

# %%
white_wine.hist(bins=15, color='grey', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))
plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)
# Out:
# Text(0.65, 1.25, 'White Wine Univariate Plots')

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,5))
plt.subplot(1,2,1)
sns.histplot(data=red_wine,x="residual sugar", color="red", bins=15)
plt.title("Red Wine")
plt.xlabel("Residual Sugar")
plt.ylabel("Frequency")
plt.xticks(np.arange(0, 16, step=2.5))
plt.yticks(np.arange(0, 3000, step=500))

plt.subplot(1,2,2)
sns.histplot(data=white_wine, x="residual sugar", color="black", fill=False, bins=15)
plt.title("White Wine")
plt.xlabel("Residual Sugar")
plt.ylabel("Frequency")
plt.yticks(np.arange(0, 3000, step=500))
fig.tight_layout(pad=4)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,5), sharey=True)
plt.subplot(1,2,1)
sns.histplot(data=red_wine,x="sulphates", color="red", bins=15)
plt.title("Red Wine")
plt.xlabel("Sulphates")
plt.ylabel("Frequency")

plt.subplot(1,2,2)
sns.histplot(data=white_wine, x="sulphates", color="black", fill=False, bins=15)
plt.title("White Wine")
plt.xlabel("Sulphates")
plt.ylabel("Frequency")
fig.tight_layout(pad=4)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,5), sharey=True)
plt.subplot(1,2,1)
sns.histplot(data=red_wine,x="citric acid", color="red", bins=15)
plt.title("Red Wine")
plt.xlabel("Citric Acid")
plt.ylabel("Frequency")

plt.subplot(1,2,2)
sns.histplot(data=white_wine, x="citric acid", color="black", fill=False, bins=15)
plt.title("White Wine")
plt.xlabel("Citric Acid")
plt.ylabel("Frequency")
fig.tight_layout(pad=4)
plt.show()

# %% [markdown]
# ## Epic 2: Multivariate Analysis

# %%
num_all = all_wines.select_dtypes(include='number')
corr_all = num_all.corr()

plt.figure(figsize=(15,8))
figure = sns.heatmap(corr_all, cmap="RdBu", vmin=-1, vmax=1, annot=True,
            annot_kws={'fontsize':8, 'fontweight':'bold', },square=True, linewidth=.7, fmt=".1f")
plt.show()

# %%
g = sns.jointplot(
    data=red_wine,
    x='quality', 
    y='sulphates',
    color="red",
    kind="scatter", 
    marginal_ticks=True, 
    marginal_kws=dict(bins=15),
    height=6,
    space=0.5,

)
plt.suptitle("Red Wine Sulphates - Quality", fontsize=16,  y=1.02)
plt.show()

# %%
# g = sns.jointplot(data=red_wine, x="quality", y="sulphates", color="r", height=6)
# g.plot_joint(sns.scatterplot, color="r")

# %%
g = sns.jointplot(
    data=white_wine,
    x='quality', 
    y='sulphates',
    color="#eccd13",
    kind="scatter", 
    marginal_ticks=True, 
    marginal_kws=dict(bins=15),
    height=6,
    space=0.5,

)
plt.suptitle("White Wine Sulphates - Quality", fontsize=16,  y=1.02)
plt.show()

# %%
g = sns.jointplot(
    data=red_wine,
    x='quality', 
    y='pH',
    color="red",
    kind="scatter", 
    marginal_ticks=True, 
    marginal_kws=dict(bins=15),
    height=6,
    space=0.5,

)
plt.suptitle("Red Wine pH - Quality", fontsize=16,  y=1.02)
plt.show()

# %%
sns.scatterplot(data=red_wine, x="alcohol", y="sulphates", hue="quality_label")
plt.title("Red Wines - Sulphates, Alcohol and Quality")
plt.show()

# %%
sns.scatterplot(data=white_wine, x="fixed acidity", y="density", hue="quality_label")
plt.title("White Wines - Fixed Acidity, Density and Quality")
plt.show()

# %%
sns.scatterplot(data=white_wine, x="volatile acidity", y="density", hue="quality_label")
plt.title("White Wines - Volatile Acidity, Density and Quality")
plt.show()

# %%
sns.scatterplot(data=white_wine, x="chlorides", y="density", hue="quality_label")
plt.title("White Wines - Chlorides, Density and Quality")
plt.show()

# %%
sns.scatterplot(data=red_wine, x="chlorides", y="density", hue="quality_label")
plt.title("Red Wines - Chlorides, Density and Quality")
plt.show()

# %%
sns.scatterplot(data=red_wine, x="chlorides", y="sulphates", hue="quality_label", palette="deep", edgecolor="black", alpha=0.7)
plt.title("Red Wines - Chlorides, Sulphates and Quality")
plt.show()
